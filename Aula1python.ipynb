# %%
# !python --version
# Out:
# Python 3.7.13

# %% [markdown]
# #Ex 1) Programa que leia 2 strings

# %%
string_1 = input('diga qual é a frase ')
# Out:
# diga qual é a frase dale gremio

# %%
print(string_1)
# Out:
# dale gremio

# %%
string_2 = input('diga qual é a frase ')
# Out:
# diga qual é a frase que soninhu :(

# %%
print(string_2)
# Out:
# que soninhu :(

# %% [markdown]
# #Ex 2) Saber o conteudo e o tamanho delas

# %%
len(string_1)
# Out:
# 11

# %%
print(len(string_2))
# Out:
# 14

# %%
len(string_1)==len(string_2)
# Out:
# False

# %%
dif = len(string_2)-len(string_1)
print(dif)
# Out:
# 3

# %% [markdown]
# #Ex 3) usuario diz seu nome e o programa reverte ele em letras maiusculas

# %%
string_3 = input('forneça seu nome porra, pf :D ')
# Out:
# forneça seu nome porra, pf :D alysson

# %%
nome_invertido = string_3[::-1]
nome_maiusculo = nome_invertido.upper()
print(nome_maiusculo)
# Out:
# NOSSYLA

# %%
print(string_3[:-4])
# Out:
# aly

# %%
print(string_3[0].upper())
# Out:
# A

# %%
print(string_2.title())
# Out:
# Que Soninhu :(

# %%
print(string_2.title().replace(" ","Fala dele"))
# Out:
# QueFala deleSoninhuFala dele:(

# %% [markdown]
# #Ex 4) programa q peça para add 2 nmr

# %%
a = float(input('digita o primeiro nmr bro: '))
b = float(input('digita o segundo nmr bro: '))
# Out:
# digita o primeiro nmr bro: 0.34
# digita o segundo nmr bro: 36

# %%
print(a,b)
# Out:
# 0.34 36.0

# %%
print(f" se tu n tem a capacidade de meter na calculadora, a média de a e b deu: {(a+b)/2}")
# Out:
#  se tu n tem a capacidade de meter na calculadora, a média de a e b deu: 18.17

# %% [markdown]
# #Ex 5) Programa q peça um Douglas Costa e calcule a aŕea do circulo

# %%
raio = float(input('digita o DC ai bro: '))
área = raio**2*3.14159265
print(f"toma a area bro: {área}")
# Out:
# digita o DC ai bro: 10
# toma a area bro: 314.159265
